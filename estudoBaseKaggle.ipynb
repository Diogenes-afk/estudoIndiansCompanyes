# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Companies_Information.csv")

# %%
df
# Out:
#        Unnamed: 0   company_name  rating  company_reviews   company_age  \
# 0               0            TCS     3.9  (54.2k Reviews)  55 years old
# 1               1            TCS     3.9  (54.2k Reviews)  55 years old
# 2               2      Accenture     4.1  (34.4k Reviews)  34 years old
# 3               3            TCS     3.9  (54.2k Reviews)  55 years old
# 4               4      Accenture     4.1  (34.4k Reviews)  34 years old
# ...           ...            ...     ...              ...           ...
# 46030       46030         BYJU'S     3.4  (14.4k Reviews)  12 years old
# 46031       46031    Tata Motors     4.1  (12.5k Reviews)  78 years old
# 46032       46032       Flipkart     4.2  (12.8k Reviews)  16 years old
# 46033       46033            WNS     3.7   (7.4k Reviews)  27 years old
# 46034       46034  IndusInd Bank     3.8     (7k Reviews)  29 years old
#
#              number_of_employees
# 0      1 Lakh+ Employees (India)
# 1      1 Lakh+ Employees (India)
# ...

# %%
df['rating'].mean()
# Out:
# 3.9640860215053766

# %%
##Avaliando dataset
notas = df.loc[df['company_name'] == "IndusInd Bank"]

# %%
## media das empreas de tecnologia da india
sns.countplot(x = df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
semDup = df.drop_duplicates(subset=['company_name', 'rating'])
semDup

# %%
##tratando a coluna reviews
rev=[]
for i in df['company_reviews']:
    a=i.split(sep='k')[0][1:]
    rev.append(float(a)*1000)
rev

# %%
##tratando a coluna idade
age=[]
for i in df['company_age']:
    a=i.split(sep=' ')[0]
    age.append(a)
age

# %%
df['company_reviews'] = pd.Series(rev)
df['company_age'] = pd.Series(age).astype(int)

# %%
# Out:
#    Unnamed: 0 company_name  rating  company_reviews company_age  \
# 0           0          TCS     3.9          54200.0          55
# 1           1          TCS     3.9          54200.0          55
# 2           2    Accenture     4.1          34400.0          34
# 3           3          TCS     3.9          54200.0          55
# 4           4    Accenture     4.1          34400.0          34
#
#          number_of_employees
# 0  1 Lakh+ Employees (India)
# 1  1 Lakh+ Employees (India)
# 2  1 Lakh+ Employees (India)
# 3  1 Lakh+ Employees (India)
# 4  1 Lakh+ Employees (India)

# %%
sns.set_color_codes("muted")
sns.barplot(x="company_reviews", y="company_name", data=df,
            label="total", color="b")
# Out:
# <Axes: xlabel='company_reviews', ylabel='company_name'>

# %%
plt.scatter(df['company_age'], df['rating'])

# %%
sns.countplot(x = df['number_of_employees'])
# Out:
# <Axes: xlabel='number_of_employees', ylabel='count'>
